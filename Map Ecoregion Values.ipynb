# %%
from mpl_toolkits.basemap import Basemap
import matplotlib.pyplot as plt
import pandas as pd
from matplotlib.patches import Polygon
from matplotlib.collections import PatchCollection
from matplotlib.patches import PathPatch

# %%
regions = ['Cascades','East Cascades','North Cascades','Sierra','Klamath','Northern Rockies','Middle Rockies',
           'Canadian Rockies','Idaho Batholith','Blue Mountains','North Basin and Range','Wasatch',
           'Southern Rockies','Central Basin and Range','Coast Range']
regions2 = ['cascades','eastcascades','northcascades','sierra','klamath','northernrockies','middlerockies',
           'canadianrockies','idahobatholith','bluemountains','nbar','wasatch',
           'southernrockies','cbar','coastrange']
regions.sort()

# %%
shapes = !ls ./data/ecoregions/subsets/*_wgs84.shp # grab the shapefiles

# %%
len(shapes)
# Out:
# 15

# %%
map = Basemap(llcrnrlon=-127.5,llcrnrlat=30.,urcrnrlon=-100.,urcrnrlat=50.,
             resolution='i', projection='merc')

# %%
regions2.sort()

# %%
regions2
# Out:
# ['bluemountains',
#  'canadianrockies',
#  'cascades',
#  'cbar',
#  'coastrange',
#  'eastcascades',
#  'idahobatholith',
#  'klamath',
#  'middlerockies',
#  'nbar',
#  'northcascades',
#  'northernrockies',
#  'sierra',
#  'southernrockies',
#  'wasatch']

# %%
fig = plt.figure(figsize=(10,10))
ax = fig.add_subplot(111)
map.drawcoastlines()
map.drawcountries()
map.drawstates()

pth = './data/ecoregions/subsets/'

for shp,er in zip(shapes,regions2):
    fpath = pth+shp.split('/')[-1].split('.')[0]
    map.readshapefile(fpath,er,color = 'k')
    
shapes2 = [map.bluemountains,map.canadianrockies,map.cascades,map.cbar,map.coastrange,map.eastcascades,
         map.idahobatholith,map.klamath, map.middlerockies, map.nbar,map.northcascades, map.northernrockies,
         map.sierra, map.southernrockies, map.wasatch]

for shape in shapes2:
    ptchs = []
    ptchs.append(Polygon(np.array(shape), True))
    ax.add_collection(PatchCollection(ptchs, facecolor='m', edgecolor='k', linewidths = 1., zorder=2))
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-27-e90ec70d58d4> in <module>()
#      17 for shape in shapes2:
#      18     ptchs = []
# ---> 19     ptchs.append(Polygon(np.array(shape), True))
#      20     ax.add_collection(PatchCollection(ptchs, facecolor='m', edgecolor='k', linewidths = 1., zorder=2))
#
# /Users/barnhatb/anaconda/lib/python2.7/site-packages/matplotlib/patches.pyc in __init__(self, xy, closed, **kwargs)
#     856         Patch.__init__(self, **kwargs)
#     857         self._closed = closed
# --> 858         self.set_xy(xy)
#     859
#     860     def get_path(self):
#
# /Users/barnhatb/anaconda/lib/python2.7/site-packages/matplotlib/patches.pyc in set_xy(self, xy)
#     924             if len(xy) > 2 and (xy[0] == xy[-1]).all():
#     925                 xy = xy[:-1]
# --> 926         self._path = Path(xy, closed=self._closed)
#     927
# ...

# %%
tmp = np.array(shape)
tmp2 = Polygon(tmp,True)
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-31-5a51ec6a7c97> in <module>()
#       1 tmp = np.array(shape)
# ----> 2 tmp2 = Polygon(tmp,True)
#
# /Users/barnhatb/anaconda/lib/python2.7/site-packages/matplotlib/patches.pyc in __init__(self, xy, closed, **kwargs)
#     856         Patch.__init__(self, **kwargs)
#     857         self._closed = closed
# --> 858         self.set_xy(xy)
#     859
#     860     def get_path(self):
#
# /Users/barnhatb/anaconda/lib/python2.7/site-packages/matplotlib/patches.pyc in set_xy(self, xy)
#     924             if len(xy) > 2 and (xy[0] == xy[-1]).all():
#     925                 xy = xy[:-1]
# --> 926         self._path = Path(xy, closed=self._closed)
#     927
#     928     _get_xy = get_xy
#
# ...

# %%
shp.split('/')[-1].split('.')[0]
# Out:
# 'blue_mtns'

# %%
patches
# Out:
# []
